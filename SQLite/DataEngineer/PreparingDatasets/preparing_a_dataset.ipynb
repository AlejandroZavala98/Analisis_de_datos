# %%
# Import libraries
import os
import pandas as pd
import sqlite3

# %%
# Set up environment
try:
    path_sources = os.chdir("../Sources") # Back one folder in current directory
except:
    print("Path does not exists")

# %%
db_etl = 'ADV_MX.db'
target_table = 'SALES2013AND2014'
xlsx_name = 'SalesFile.xlsx'
usr = 'usrhs'

# %%
# Enable connection

def sqlite_connection(db_file):
    try:
        connection_path = sqlite3.connect(db_file)
        cursor_obj = connection_path.cursor()
        print(f"SUCCESS CONNECTION\nVersion SQlite: {sqlite3.version}")
        return connection_path,cursor_obj
    except sqlite3.Error as e:
        print(f"FAILED CONNECTION\nERROR is: {e}")

# %%
con,cur = sqlite_connection(db_etl)
# Out:
# SUCCESS CONNECTION
# Version SQlite: 2.6.0

# %%
def sqlite_query(connection_path,query_str):
    try:
        connection_path.execute(query_str)
        connection_path.commit()
        print("SUCCESS EXECUTION")
    except Exception as e:
        print("FAILED EXECUTION\n")
        print(e)

# %%
# File to load
df_sales = pd.read_excel(xlsx_name)

# %%
df_sales.shape[0] # Total Records
# Out:
# 51

# %%
df_sales # FIRST RECORDS
# Out:
#                   Product   Discount Band    Units Sold  \
# 0         TrailBlazer 1000       non value          958
# 1         TrailBlazer 2000            Low          2529
# 2         SpeedMaster 1000            Low           918
# 3         SpeedMaster 2000            Low          1774
# 4            Explorer 1000            Low           866
# 5            Explorer 2000         Medium           NaN
# 6       GravityMaster 1000         Medium          1679
# 7       GravityMaster 2000         Medium           588
# 8          Pathfinder 1000         Medium          1366
# 9          Pathfinder 2000         Medium           973
# 10            Voyager 1000           High          2072
# 11            Voyager 2000           High   six hundred
# 12         Adventurer 1000           High          2641
# 13         Adventurer 2000           High          1727
# 14       EnduroMaster 1000           High           663
# 15       EnduroMaster 2000       non value         2146
# 16           FatTrail 1000            Low          1445
# 17           FatTrail 2000       non value         1728
# 18         CrossRider 1000            Low          1901
# 19         CrossRider 2000            Low           349
# 20        DuoExplorer 1000         Medium          2861
# 21        DuoExplorer 2000         Medium           727
# 22         E-Mountain 1000         Medium        3244,5
# 23         E-Mountain 2000         Medium          2460
# 24           UrbanEco 1000         Medium          1038
# 25           UrbanEco 2000           High           853
# 26       GravelMaster 1000           High          1773
# 27       GravelMaster 2000           High          2708
# 28           FoldAway 1000            Low          2861
# 29           FoldAway 2000       non value          293
# 30      E-TrailBlazer 1000            Low           NaN
# 31      E-TrailBlazer 2000         Medium           564
# 32         CommutePro 1000           High           545
# 33         CommutePro 2000       non value          168
# 34          AeroSpeed 1000           High           856
# 35          AeroSpeed 2000       non value          346
# 36       ReclineRider 1000           High          3424
# 37       ReclineRider 2000         Medium   six hundred
# 38  DownhillDominator 1000           High           987
# 39  DownhillDominator 2000           High           685
# 40     LittleBalancer 1000            Low          5758
# 41     LittleBalancer 2000           High   six hundred
# 42           UrbanEco 1000         Medium          1038
# 43           UrbanEco 2000           High           853
# 44       GravelMaster 1000           High          1773
# 45       GravelMaster 2000           High          2708
# 46           FoldAway 1000            Low          2861
# 47        SpeedMaster 2000            Low          1774
# 48           Explorer 1000            Low           866
# 49         Pathfinder 2000         Medium           973
# 50         Pathfinder 2000         Medium           973
#
#      Manufacturing Price    Sale Price      Sales     Profit         Date  \
# 0                     5.0         300.0  287400.00   47900.00  2014-08-01
# 1                    10.0           7.0   17525.97    4880.97  2014-07-01
# 2                    10.0         300.0  269892.00   40392.00  2014-05-01
# 3                    10.0         125.0  215097.50    2217.50  2014-03-01
# 4                   250.0           NaN    9976.32    7378.32  2014-05-01
# 5                     NaN          15.0    7908.75    2358.75  2014-01-01
# 6                   260.0         350.0  552391.00  115851.00  2014-09-01
# 7                   120.0          20.0   10936.80    5056.80  2013-12-01
# 8                   260.0          20.0   25134.40   11474.40  2014-06-01
# 9                    10.0          20.0        NaN    7978.60  2014-03-01
# 10                  260.0          15.0   27972.00    7252.00  2014-12-01
# 11                    5.0          15.0    8936.40    2166.40  2014-03-01
# 12                   10.0          20.0   45953.40   19543.40  2014-02-01
# 13                    5.0           7.0   10396.54    1761.54  2013-10-01
# 14                  120.0         125.0   70443.75   -9116.25  2014-09-01
# 15                    5.0           7.0   15022.00        NaN  2014-09-01
# 16                    3.0          12.0   17166.60   12831.60  2014-09-01
# 17                   10.0         300.0  508032.00   76032.00         NaN
# 18                   10.0          12.0   22127.64   16424.64  2014-06-01
# 19                  250.0         350.0  117264.00   26524.00  2013-09-01
# 20                  120.0          15.0   40769.25   12159.25  2014-01-01
# 21                  260.0         350.0  239183.00   50163.00  2013-10-01
# 22                  250.0           NaN   36208.62   26475.12  2014-01-01
# 23                  260.0         300.0  678960.00   63960.00  2014-09-01
# 24                   10.0          20.0   18891.60    8511.60  2014-06-01
# 25                  260.0         300.0  230310.00   17060.00  2014-12-01
# 26                    5.0         300.0  468072.00   24822.00  2014-04-01
# 27                   10.0          20.0        NaN   20039.20  2014-02-01
# 28                  120.0          20.0   22127.64    7978.60  2013-10-01
# 29                  260.0          20.0  117264.00    7252.00  2013-12-01
# 30                   10.0          20.0   40769.25    2166.40  2014-06-01
# 31                  260.0          15.0  239183.00   19543.40  2014-08-01
# 32                    5.0          15.0   36208.62    7978.60  2014-07-01
# 33                   10.0          20.0  678960.00    7252.00  2014-09-01
# 34                    5.0           7.0   18891.60    2166.40         NaN
# 35                  120.0         125.0    9976.32   19543.40  2014-07-01
# 36                  260.0           7.0    9976.32        NaN  2014-12-01
# 37                    NaN          12.0        NaN    2217.50  2014-10-01
# 38                  260.0         300.0        NaN   16424.64  2014-07-01
# 39                  260.0          12.0   27972.00   26524.00  2014-03-01
# 40                   10.0         350.0    8936.40   12159.25  2014-12-01
# 41                  260.0          15.0   45953.40   50163.00  2014-09-01
# 42                   10.0          20.0   18891.60    8511.60         NaN
# 43                  260.0         300.0  230310.00   17060.00  2014-12-01
# 44                    5.0         300.0  468072.00   24822.00  2014-04-01
# 45                   10.0          20.0        NaN   20039.20  2014-02-01
# 46                  120.0          20.0   22127.64    7978.60  2013-10-01
# 47                   10.0         125.0  215097.50    2217.50  2014-03-01
# 48                  250.0           NaN    9976.32    7378.32  2014-05-01
# 49                   10.0          20.0        NaN    7978.60  2014-03-01
# 50                   10.0          20.0        NaN    7978.60  2014-03-01
#
#     Month Number
# 0            8.0
# 1            7.0
# 2            5.0
# 3            3.0
# 4            5.0
# 5            1.0
# 6            9.0
# 7           12.0
# 8            6.0
# 9            3.0
# 10          12.0
# 11           3.0
# 12           2.0
# 13          10.0
# 14           9.0
# 15           9.0
# 16           9.0
# 17           5.0
# 18           6.0
# 19           9.0
# 20           1.0
# 21          10.0
# 22           1.0
# 23           9.0
# 24           6.0
# 25          12.0
# 26           4.0
# 27           2.0
# 28          10.0
# 29          12.0
# 30           6.0
# 31           8.0
# 32           7.0
# 33           9.0
# 34          10.0
# 35           7.0
# 36          12.0
# 37          10.0
# 38           7.0
# 39           3.0
# 40          12.0
# 41           9.0
# 42           6.0
# 43          12.0
# 44           4.0
# 45           2.0
# 46          10.0
# 47           3.0
# 48           5.0
# 49           3.0
# 50           3.0

# %%
# Define raw table extructure with guidelines

# Drop raw table
sqlite_query(con,f"""DROP TABLE IF EXISTS {target_table + '_RAW'};""")

sales_raw = f"""
            CREATE TABLE {target_table + '_RAW'} (
            "PRODUCT_NAME" TEXT,
            "DISCOUNT_BAND" TEXT,
            "UNITS_SOLD" TEXT,
            "MANUFACTURING_PRICE" TEXT,
            "SALE_PRICE" TEXT,
            "SALES" TEXT,
            "PROFIT" TEXT,
            "DATE" TEXT,
            "MONTH_NUMBER" TEXT);"""

sqlite_query(con,sales_raw)
# Out:
# SUCCESS EXECUTION
# SUCCESS EXECUTION

# %%
# Insert raw data into raw table
def sqlite_insert(connection_path,query_insert,df_pandas):
    try:
        print(f'Total records to insert are: {df_pandas.shape[0]} and the total columns are: {df_pandas.shape[1]}')
        data_to_add = [tuple(r) for r in df_pandas.to_numpy()]
        connection_path.executemany(query_insert,data_to_add)
        connection_path.commit()
        print('SUCCESS INSERT')
    except Exception as e:
        print("Failed execution\n")
        print(e)

# %%
insert_raw = f"""INSERT INTO {target_table + '_RAW'}
                ("PRODUCT_NAME","DISCOUNT_BAND","UNITS_SOLD","MANUFACTURING_PRICE","SALE_PRICE","SALES","PROFIT","DATE","MONTH_NUMBER")
                VALUES (?,?,?,?,?,?,?,?,?)"""

sqlite_insert(con,insert_raw,df_sales)
# Out:
# Total records to insert are: 51 and the total columns are: 9
# SUCCESS INSERT

# %%
# Check values and see the issues in the different columns

df_raw = pd.read_sql_query(f"""SELECT * FROM {target_table + '_RAW'}""", con)

print(f"Total records are: {df_raw.shape[0]}")
display(df_raw)
# Out:
# Total records are: 51
#               PRODUCT_NAME DISCOUNT_BAND   UNITS_SOLD MANUFACTURING_PRICE  \
# 0         TrailBlazer 1000     non value          958                 5.0
# 1         TrailBlazer 2000          Low          2529                10.0
# 2         SpeedMaster 1000          Low           918                10.0
# 3         SpeedMaster 2000          Low          1774                10.0
# 4            Explorer 1000          Low           866               250.0
# 5            Explorer 2000       Medium          None                None
# 6       GravityMaster 1000       Medium          1679               260.0
# 7       GravityMaster 2000       Medium           588               120.0
# 8          Pathfinder 1000       Medium          1366               260.0
# 9          Pathfinder 2000       Medium           973                10.0
# 10            Voyager 1000         High          2072               260.0
# 11            Voyager 2000         High   six hundred                 5.0
# 12         Adventurer 1000         High          2641                10.0
# 13         Adventurer 2000         High          1727                 5.0
# 14       EnduroMaster 1000         High           663               120.0
# 15       EnduroMaster 2000     non value         2146                 5.0
# 16           FatTrail 1000          Low          1445                 3.0
# 17           FatTrail 2000     non value         1728                10.0
# 18         CrossRider 1000          Low          1901                10.0
# 19         CrossRider 2000          Low           349               250.0
# 20        DuoExplorer 1000       Medium          2861               120.0
# 21        DuoExplorer 2000       Medium           727               260.0
# 22         E-Mountain 1000       Medium        3244,5               250.0
# 23         E-Mountain 2000       Medium          2460               260.0
# 24           UrbanEco 1000       Medium          1038                10.0
# 25           UrbanEco 2000         High           853               260.0
# 26       GravelMaster 1000         High          1773                 5.0
# 27       GravelMaster 2000         High          2708                10.0
# 28           FoldAway 1000          Low          2861               120.0
# 29           FoldAway 2000     non value          293               260.0
# 30      E-TrailBlazer 1000          Low          None                10.0
# 31      E-TrailBlazer 2000       Medium           564               260.0
# 32         CommutePro 1000         High           545                 5.0
# 33         CommutePro 2000     non value          168                10.0
# 34          AeroSpeed 1000         High           856                 5.0
# 35          AeroSpeed 2000     non value          346               120.0
# 36       ReclineRider 1000         High          3424               260.0
# 37       ReclineRider 2000       Medium   six hundred                None
# 38  DownhillDominator 1000         High           987               260.0
# 39  DownhillDominator 2000         High           685               260.0
# 40     LittleBalancer 1000          Low          5758                10.0
# 41     LittleBalancer 2000         High   six hundred               260.0
# 42           UrbanEco 1000       Medium          1038                10.0
# 43           UrbanEco 2000         High           853               260.0
# 44       GravelMaster 1000         High          1773                 5.0
# 45       GravelMaster 2000         High          2708                10.0
# 46           FoldAway 1000          Low          2861               120.0
# 47        SpeedMaster 2000          Low          1774                10.0
# 48           Explorer 1000          Low           866               250.0
# 49         Pathfinder 2000       Medium           973                10.0
# 50         Pathfinder 2000       Medium           973                10.0
#
#    SALE_PRICE     SALES    PROFIT        DATE MONTH_NUMBER
# 0       300.0  287400.0   47900.0  2014-08-01          8.0
# 1         7.0  17525.97   4880.97  2014-07-01          7.0
# 2       300.0  269892.0   40392.0  2014-05-01          5.0
# 3       125.0  215097.5    2217.5  2014-03-01          3.0
# 4        None   9976.32   7378.32  2014-05-01          5.0
# 5        15.0   7908.75   2358.75  2014-01-01          1.0
# 6       350.0  552391.0  115851.0  2014-09-01          9.0
# 7        20.0   10936.8    5056.8  2013-12-01         12.0
# 8        20.0   25134.4   11474.4  2014-06-01          6.0
# 9        20.0      None    7978.6  2014-03-01          3.0
# 10       15.0   27972.0    7252.0  2014-12-01         12.0
# 11       15.0    8936.4    2166.4  2014-03-01          3.0
# 12       20.0   45953.4   19543.4  2014-02-01          2.0
# 13        7.0  10396.54   1761.54  2013-10-01         10.0
# 14      125.0  70443.75  -9116.25  2014-09-01          9.0
# 15        7.0   15022.0      None  2014-09-01          9.0
# 16       12.0   17166.6   12831.6  2014-09-01          9.0
# 17      300.0  508032.0   76032.0        None          5.0
# 18       12.0  22127.64  16424.64  2014-06-01          6.0
# 19      350.0  117264.0   26524.0  2013-09-01          9.0
# 20       15.0  40769.25  12159.25  2014-01-01          1.0
# 21      350.0  239183.0   50163.0  2013-10-01         10.0
# 22       None  36208.62  26475.12  2014-01-01          1.0
# 23      300.0  678960.0   63960.0  2014-09-01          9.0
# 24       20.0   18891.6    8511.6  2014-06-01          6.0
# 25      300.0  230310.0   17060.0  2014-12-01         12.0
# 26      300.0  468072.0   24822.0  2014-04-01          4.0
# 27       20.0      None   20039.2  2014-02-01          2.0
# 28       20.0  22127.64    7978.6  2013-10-01         10.0
# 29       20.0  117264.0    7252.0  2013-12-01         12.0
# 30       20.0  40769.25    2166.4  2014-06-01          6.0
# 31       15.0  239183.0   19543.4  2014-08-01          8.0
# 32       15.0  36208.62    7978.6  2014-07-01          7.0
# 33       20.0  678960.0    7252.0  2014-09-01          9.0
# 34        7.0   18891.6    2166.4        None         10.0
# 35      125.0   9976.32   19543.4  2014-07-01          7.0
# 36        7.0   9976.32      None  2014-12-01         12.0
# 37       12.0      None    2217.5  2014-10-01         10.0
# 38      300.0      None  16424.64  2014-07-01          7.0
# 39       12.0   27972.0   26524.0  2014-03-01          3.0
# 40      350.0    8936.4  12159.25  2014-12-01         12.0
# 41       15.0   45953.4   50163.0  2014-09-01          9.0
# 42       20.0   18891.6    8511.6        None          6.0
# 43      300.0  230310.0   17060.0  2014-12-01         12.0
# 44      300.0  468072.0   24822.0  2014-04-01          4.0
# 45       20.0      None   20039.2  2014-02-01          2.0
# 46       20.0  22127.64    7978.6  2013-10-01         10.0
# 47      125.0  215097.5    2217.5  2014-03-01          3.0
# 48       None   9976.32   7378.32  2014-05-01          5.0
# 49       20.0      None    7978.6  2014-03-01          3.0
# 50       20.0      None    7978.6  2014-03-01          3.0

# %%
""" Data cleaning using stage tables
Let see some issues in this dataset
1. Notices UNITS_SOLD, SALE_PRICE, SALES and PROFIT has null values 
2. Notices UNITS_SOLD has text quantities
3. Notices DISCOUNT_BAND has a value not requiered
4. Notices DATE has null values, business say this data correspond to date 03 March 2023
5. Notices business does not requiere MANUFACTURING_PRICE null
6. Notices in this records are duplicated values
7. Add control columns
"""

insert_stg = f"""SELECT DISTINCT
                PRODUCT_NAME,
                CASE WHEN DISCOUNT_BAND = 'non value' THEN NULL ELSE DISCOUNT_BAND END AS DISCOUNT_BAND,
                COALESCE(CASE WHEN UNITS_SOLD = 'six hundred' THEN 600 ELSE UNITS_SOLD END,0) AS UNITS_SOLD,
                MANUFACTURING_PRICE,
                COALESCE(SALE_PRICE,0) AS SALE_PRICE,
                COALESCE(SALES,0) AS SALES,
                COALESCE(PROFIT,0) AS PROFIT,
                COALESCE(DATE,'2023-03-03') AS DATE,
                STRFTIME('%m',COALESCE(DATE,'2023-03-03')) AS MONTH_NUMBER,
                '{usr}' AS USR_LOAD,
                DATE('now') AS CREATE_DT
                FROM {target_table+ '_RAW'}
                WHERE MANUFACTURING_PRICE IS NOT NULL; """

# %%
# Define target table extructure with guidelines

sales_tgt = f"""
            CREATE TABLE IF NOT EXISTS {target_table} (
            "PRODUCT_NAME" TEXT,
            "DISCOUNT_BAND" TEXT,
            "UNITS_SOLD" TEXT,
            "MANUFACTURING_PRICE" TEXT,
            "SALE_PRICE" REAL,
            "SALES" REAL,
            "PROFIT" REAL,
            "DATE" TEXT,
            "MONTH_NUMBER" INTEGER,
            "USR_LOAD" TEXT,
            "CREATE_DT" TEXT);"""

sqlite_query(con,sales_tgt)

insert_tgt = f"""INSERT INTO {target_table}
            {insert_stg}"""

sqlite_query(con,insert_tgt)
# Out:
# SUCCESS EXECUTION
# SUCCESS EXECUTION

# %%
df_describe = pd.read_sql_query(f"""PRAGMA table_info({target_table});""", con)

display(df_describe)
# Out:
#     cid                 name     type  notnull dflt_value  pk
# 0     0         PRODUCT_NAME     TEXT        0       None   0
# 1     1        DISCOUNT_BAND     TEXT        0       None   0
# 2     2           UNITS_SOLD     TEXT        0       None   0
# 3     3  MANUFACTURING_PRICE     TEXT        0       None   0
# 4     4           SALE_PRICE     REAL        0       None   0
# 5     5                SALES     REAL        0       None   0
# 6     6               PROFIT     REAL        0       None   0
# 7     7                 DATE     TEXT        0       None   0
# 8     8         MONTH_NUMBER  INTEGER        0       None   0
# 9     9             USR_LOAD     TEXT        0       None   0
# 10   10            CREATE_DT     TEXT        0       None   0

# %%
# Target table

display(pd.read_sql_query(f"""SELECT COUNT(*) FROM {target_table}""", con))
# Out:
#    COUNT(*)
# 0        41

# %%
display(pd.read_sql_query(f"""SELECT * FROM {target_table}""", con))
# Out:
#               PRODUCT_NAME DISCOUNT_BAND UNITS_SOLD MANUFACTURING_PRICE  \
# 0         TrailBlazer 1000          None        958                 5.0
# 1         TrailBlazer 2000          Low        2529                10.0
# 2         SpeedMaster 1000          Low         918                10.0
# 3         SpeedMaster 2000          Low        1774                10.0
# 4            Explorer 1000          Low         866               250.0
# 5       GravityMaster 1000       Medium        1679               260.0
# 6       GravityMaster 2000       Medium         588               120.0
# 7          Pathfinder 1000       Medium        1366               260.0
# 8          Pathfinder 2000       Medium         973                10.0
# 9             Voyager 1000         High        2072               260.0
# 10            Voyager 2000         High         600                 5.0
# 11         Adventurer 1000         High        2641                10.0
# 12         Adventurer 2000         High        1727                 5.0
# 13       EnduroMaster 1000         High         663               120.0
# 14       EnduroMaster 2000          None       2146                 5.0
# 15           FatTrail 1000          Low        1445                 3.0
# 16           FatTrail 2000          None       1728                10.0
# 17         CrossRider 1000          Low        1901                10.0
# 18         CrossRider 2000          Low         349               250.0
# 19        DuoExplorer 1000       Medium        2861               120.0
# 20        DuoExplorer 2000       Medium         727               260.0
# 21         E-Mountain 1000       Medium      3244,5               250.0
# 22         E-Mountain 2000       Medium        2460               260.0
# 23           UrbanEco 1000       Medium        1038                10.0
# 24           UrbanEco 2000         High         853               260.0
# 25       GravelMaster 1000         High        1773                 5.0
# 26       GravelMaster 2000         High        2708                10.0
# 27           FoldAway 1000          Low        2861               120.0
# 28           FoldAway 2000          None        293               260.0
# 29      E-TrailBlazer 1000          Low           0                10.0
# 30      E-TrailBlazer 2000       Medium         564               260.0
# 31         CommutePro 1000         High         545                 5.0
# 32         CommutePro 2000          None        168                10.0
# 33          AeroSpeed 1000         High         856                 5.0
# 34          AeroSpeed 2000          None        346               120.0
# 35       ReclineRider 1000         High        3424               260.0
# 36  DownhillDominator 1000         High         987               260.0
# 37  DownhillDominator 2000         High         685               260.0
# 38     LittleBalancer 1000          Low        5758                10.0
# 39     LittleBalancer 2000         High         600               260.0
# 40           UrbanEco 1000       Medium        1038                10.0
#
#     SALE_PRICE      SALES     PROFIT        DATE  MONTH_NUMBER USR_LOAD  \
# 0        300.0  287400.00   47900.00  2014-08-01             8    usrhs
# 1          7.0   17525.97    4880.97  2014-07-01             7    usrhs
# 2        300.0  269892.00   40392.00  2014-05-01             5    usrhs
# 3        125.0  215097.50    2217.50  2014-03-01             3    usrhs
# 4          0.0    9976.32    7378.32  2014-05-01             5    usrhs
# 5        350.0  552391.00  115851.00  2014-09-01             9    usrhs
# 6         20.0   10936.80    5056.80  2013-12-01            12    usrhs
# 7         20.0   25134.40   11474.40  2014-06-01             6    usrhs
# 8         20.0       0.00    7978.60  2014-03-01             3    usrhs
# 9         15.0   27972.00    7252.00  2014-12-01            12    usrhs
# 10        15.0    8936.40    2166.40  2014-03-01             3    usrhs
# 11        20.0   45953.40   19543.40  2014-02-01             2    usrhs
# 12         7.0   10396.54    1761.54  2013-10-01            10    usrhs
# 13       125.0   70443.75   -9116.25  2014-09-01             9    usrhs
# 14         7.0   15022.00       0.00  2014-09-01             9    usrhs
# 15        12.0   17166.60   12831.60  2014-09-01             9    usrhs
# 16       300.0  508032.00   76032.00  2023-03-03             3    usrhs
# 17        12.0   22127.64   16424.64  2014-06-01             6    usrhs
# 18       350.0  117264.00   26524.00  2013-09-01             9    usrhs
# 19        15.0   40769.25   12159.25  2014-01-01             1    usrhs
# 20       350.0  239183.00   50163.00  2013-10-01            10    usrhs
# 21         0.0   36208.62   26475.12  2014-01-01             1    usrhs
# 22       300.0  678960.00   63960.00  2014-09-01             9    usrhs
# 23        20.0   18891.60    8511.60  2014-06-01             6    usrhs
# 24       300.0  230310.00   17060.00  2014-12-01            12    usrhs
# 25       300.0  468072.00   24822.00  2014-04-01             4    usrhs
# 26        20.0       0.00   20039.20  2014-02-01             2    usrhs
# 27        20.0   22127.64    7978.60  2013-10-01            10    usrhs
# 28        20.0  117264.00    7252.00  2013-12-01            12    usrhs
# 29        20.0   40769.25    2166.40  2014-06-01             6    usrhs
# 30        15.0  239183.00   19543.40  2014-08-01             8    usrhs
# 31        15.0   36208.62    7978.60  2014-07-01             7    usrhs
# 32        20.0  678960.00    7252.00  2014-09-01             9    usrhs
# 33         7.0   18891.60    2166.40  2023-03-03             3    usrhs
# 34       125.0    9976.32   19543.40  2014-07-01             7    usrhs
# 35         7.0    9976.32       0.00  2014-12-01            12    usrhs
# 36       300.0       0.00   16424.64  2014-07-01             7    usrhs
# 37        12.0   27972.00   26524.00  2014-03-01             3    usrhs
# 38       350.0    8936.40   12159.25  2014-12-01            12    usrhs
# 39        15.0   45953.40   50163.00  2014-09-01             9    usrhs
# 40        20.0   18891.60    8511.60  2023-03-03             3    usrhs
#
#      CREATE_DT
# 0   2023-11-17
# 1   2023-11-17
# 2   2023-11-17
# 3   2023-11-17
# 4   2023-11-17
# 5   2023-11-17
# 6   2023-11-17
# 7   2023-11-17
# 8   2023-11-17
# 9   2023-11-17
# 10  2023-11-17
# 11  2023-11-17
# 12  2023-11-17
# 13  2023-11-17
# 14  2023-11-17
# 15  2023-11-17
# 16  2023-11-17
# 17  2023-11-17
# 18  2023-11-17
# 19  2023-11-17
# 20  2023-11-17
# 21  2023-11-17
# 22  2023-11-17
# 23  2023-11-17
# 24  2023-11-17
# 25  2023-11-17
# 26  2023-11-17
# 27  2023-11-17
# 28  2023-11-17
# 29  2023-11-17
# 30  2023-11-17
# 31  2023-11-17
# 32  2023-11-17
# 33  2023-11-17
# 34  2023-11-17
# 35  2023-11-17
# 36  2023-11-17
# 37  2023-11-17
# 38  2023-11-17
# 39  2023-11-17
# 40  2023-11-17

# %%
# Close connection

con.close()
